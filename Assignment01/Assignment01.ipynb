# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

a = torch.FloatTensor([[0,1,2,3,4], [2, 3, 4, 5,6]])

print(a.dim())
print(a[: ,1])
print(a[-1][-1])

y = 10 * np.random.randn(2, 3);
print(y)

x = torch.zeros(2, 2)
x.add(2)
y = 2 * x

print(x, y)

plt.plot([1, 2, 3],  [2, 4, 6])
plt.axis([0, 10, 0, 20])
plt.show()
# Out:
# 2
# tensor([1., 3.])
# tensor(6.)
# [[-5.41118614 -4.51274696 13.98120695]
#  [ 0.32564451  5.87781474 10.07321283]]
# tensor([[0., 0.],
#         [0., 0.]]) tensor([[0., 0.],
#         [0., 0.]])

# %% [markdown]
# #This is First Assignment

# %% [markdown]
# by kimwoongsoo(김웅수)
