# %%
import torch
import numpy as np

# %%
x = torch.rand(5,3)
print(x)
# Out:
# tensor([[0.4262, 0.8974, 0.3551],
#         [0.4976, 0.0275, 0.4316],
#         [0.8844, 0.2475, 0.8551],
#         [0.7110, 0.2570, 0.4842],
#         [0.0826, 0.9548, 0.2831]])
